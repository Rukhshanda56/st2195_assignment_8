# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## Load the data
#
# Use https://data.imf.org/?sk=9D6028D4-F14A-464C-A2F2-59B2CD424B85&sId=1390030341854 to download the data and load in the data. Here 2021M1 and export information is used

# %%
import pandas as pd

trade_latest = pd.read_excel("export_2021m1.xlsx", skiprows=1, index_col=0, nrows=7)
trade_latest

#skiprows=1: skips the first row (usually used to skip metadata or titles)

#index_col=0: use column 0 (i.e., the first visible column after skipping) as the row index

#nrows=7: read only the first 7 data rows
# Out:
#                       Canada       France      Germany        Italy  \
# Canada                   NaN   182.352251   415.434050   181.372819
# France            295.809053          NaN  6499.882449  3609.601611
# Germany           765.305670  9564.520318          NaN  6580.061189
# Italy             331.691543  4508.622422  5843.193709          NaN
# Japan             664.301920   525.365888  1515.356257   365.072103
# United Kingdom    370.041409  1568.474303  2563.928364   749.513129
# United States   21217.187629  1996.406425  4516.721760  1815.032006
#
#                       Japan  United Kingdom  United States
# Canada           800.140783     1524.279961   26703.649930
# France           671.496776     2212.457674    3008.172497
# Germany         1804.535371     5353.747032   10348.494982
# Italy            687.903268     1543.974658    3610.256816
# Japan                   NaN      875.286681   10645.095673
# United Kingdom   588.939467             NaN    4036.455558
# United States   6017.644718     4670.679914            NaN

# %% [markdown]
# ## Create the network
#
# We first convert the matrix data into pair data

# %%
trade_latest = pd.melt(trade_latest.reset_index(), id_vars='index')
trade_latest.columns = ['export_country', 'import_country', 'value']

#The method pd.melt() is used to reshape a DataFrame from wide format to long format — useful for tidy data and plotting.

# %%
trade_latest.dropna(inplace=True)
trade_latest
# Out:
#     export_country  import_country         value
# 1           France          Canada    295.809053
# 2          Germany          Canada    765.305670
# 3            Italy          Canada    331.691543
# 4            Japan          Canada    664.301920
# 5   United Kingdom          Canada    370.041409
# 6    United States          Canada  21217.187629
# 7           Canada          France    182.352251
# 9          Germany          France   9564.520318
# 10           Italy          France   4508.622422
# 11           Japan          France    525.365888
# 12  United Kingdom          France   1568.474303
# 13   United States          France   1996.406425
# 14          Canada         Germany    415.434050
# 15          France         Germany   6499.882449
# 17           Italy         Germany   5843.193709
# 18           Japan         Germany   1515.356257
# 19  United Kingdom         Germany   2563.928364
# 20   United States         Germany   4516.721760
# 21          Canada           Italy    181.372819
# 22          France           Italy   3609.601611
# 23         Germany           Italy   6580.061189
# 25           Japan           Italy    365.072103
# 26  United Kingdom           Italy    749.513129
# 27   United States           Italy   1815.032006
# 28          Canada           Japan    800.140783
# 29          France           Japan    671.496776
# 30         Germany           Japan   1804.535371
# 31           Italy           Japan    687.903268
# 33  United Kingdom           Japan    588.939467
# 34   United States           Japan   6017.644718
# 35          Canada  United Kingdom   1524.279961
# 36          France  United Kingdom   2212.457674
# 37         Germany  United Kingdom   5353.747032
# 38           Italy  United Kingdom   1543.974658
# 39           Japan  United Kingdom    875.286681
# 41   United States  United Kingdom   4670.679914
# 42          Canada   United States  26703.649930
# 43          France   United States   3008.172497
# 44         Germany   United States  10348.494982
# 45           Italy   United States   3610.256816
# 46           Japan   United States  10645.095673
# 47  United Kingdom   United States   4036.455558

# %% [markdown]
# Now we can use the pairs to create the graph, with the first two columns representing the nodes and the last column representing the weight

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

for index, row in trade_latest.iterrows():
    G.add_edge(row['export_country'], row['import_country'], weight=row['value'])

# remove isolated vertices = nodes (if any)    
remove = [node for node,degree in G.degree() if degree ==0]
G.remove_nodes_from(remove)

#Setting size and colours
options = {
     'node_color': 'lightblue',
     'edge_color': 'lightblue',
     'node_size': 1,
     'width': 1,
     'alpha': 1}

# %% [markdown]
# ## Draw the graph
#
# ### Spring layout

# %%
plt.subplots(figsize=(5,5))
pos=nx.spring_layout(G)

nx.draw(G,pos=pos,font_size=9,**options)


nx.draw_networkx_labels(G,pos=pos,font_size=9)

plt.tight_layout()

plt.axis('off');

plt.show()

##the **options syntax means:

#Unpack a dictionary of keyword arguments and pass them into the function as named parameters.

# %% [markdown]
# ### Random layout

# %%
plt.subplots(figsize=(5,5))
pos=nx.random_layout(G)
nx.draw(G,pos=pos,font_size=9,**options)
nx.draw_networkx_labels(G,pos=pos,font_size=9)
plt.tight_layout()
plt.axis('off');
plt.show()

# %% [markdown]
# ### Circular layout

# %%
plt.subplots(figsize=(5,5))
pos=nx.circular_layout(G)
nx.draw(G,pos=pos,font_size=9,**options)
nx.draw_networkx_labels(G,pos=pos,font_size=9)
plt.tight_layout()
plt.axis('off');
plt.show()

# %% [markdown]
# Save the graph for part 3 of the assignment

# %%
import pickle

f = open("graph.pickle", "wb")
pickle.dump(G, file = f)
f.close()


## Opens a file named graph.pickle in write-binary mode (wb) #This file will be used to save the serialized object
## Serializes the object G (likely a NetworkX graph) and writes it into the file using pickle.dump()
## Closes the file after writing to free up system resources and ensure all data is saved
